# %% [markdown]
# # Web Scraping through TransferMarkt for Players from the other Top 5 Leagues

# %% [markdown]
# ## Importing Libraries

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import time
import os
import random

# %% [markdown]
# ## Setup

# %%
def get_soup_with_selenium(url):
    options = Options()
    options.add_argument("--headless=new")
    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument(
        "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    )
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

    try:
        driver.get(url)
        time.sleep(5)
        html = driver.page_source
    except Exception as e:
        print(f"⚠️ Failed to fetch {url}: {e}")
        html = ""
    finally:
        driver.quit()

    return BeautifulSoup(html, "html.parser")

BASE_URL = "https://www.transfermarkt.com"
LEAGUE_INFO = {
    "serie_a": {"slug": "serie-a", "code": "IT1"},
    "la_liga": {"slug": "laliga", "code": "ES1"},
    "bundesliga": {"slug": "bundesliga", "code": "L1"},
    "ligue_1": {"slug": "ligue-1", "code": "FR1"}
}

# %% [markdown]
# ## Scraping

# %% [markdown]
# ### Getting all Clubs URL

# %%
def get_club_links(slug, code):
    league_url = f"{BASE_URL}/{slug}/startseite/wettbewerb/{code}"
    soup = get_soup_with_selenium(league_url)
    table = soup.find("table", class_="items")
    club_links = []
    if table:
        for link in table.select("td.hauptlink a[href*='/startseite/verein']"):
            href = link.get("href")
            if href:
                club_url = BASE_URL + href.replace("startseite", "kader")
                club_links.append(club_url)
    return list(set(club_links))

# %% [markdown]
# ### Extracting Player Data from Club's Page

# %%
def get_players_from_club(club_url):
    attempts = 3
    for i in range(attempts):
        soup = get_soup_with_selenium(club_url)
        table = soup.find("table", class_="items")
        if table:
            break
        else:
            print(f"⚠️ Attempt {i+1}/{attempts} failed at {club_url}, retrying...")
            time.sleep(5)
    else:
        print(f"❌ No player table found at {club_url} (503 Service Unavailable)")
        return []

    players = []
    club_name_tag = soup.select_one("h1")
    club_name = club_name_tag.text.strip() if club_name_tag else "N/A"

    for row in table.select("tbody > tr.odd, tbody > tr.even"):
        try:
            name_tag = row.select_one("td.posrela table.inline-table tr td.hauptlink a")
            name = name_tag.text.strip().replace(",", "") if name_tag else "N/A"

            age = row.select_one("td.zentriert:nth-of-type(3)")
            age = age.text.strip().replace(",", "") if age else "N/A"

            nationality_imgs = row.select("td.zentriert:nth-of-type(4) img")
            nationality = " / ".join([img.get("title", "") for img in nationality_imgs])

            position_tag = row.select_one("td.posrela table.inline-table tr:nth-of-type(2) td")
            position = position_tag.text.strip().replace(",", "") if position_tag else "N/A"

            market_value_tag = row.select_one("td.rechts.hauptlink")
            market_value = market_value_tag.text.strip().replace(",", "") if market_value_tag else "N/A"

            players.append({
                "Name": name,
                "Age": age,
                "Position": position,
                "Nationality": nationality,
                "Market Value": market_value,
                "Club Name": club_name
            })
        except Exception as e:
            print(f"⚠️ Error parsing row: {e}")
            continue

    return players

# %% [markdown]
# ### Scraping through all the Leagues

# %%
for league_name, info in LEAGUE_INFO.items():
    print(f"\n=== Scraping {league_name.replace('_', ' ').title()} ===")
    all_players = []
    club_links = get_club_links(info['slug'], info['code'])
    print(f"Found {len(club_links)} clubs.")

    for idx, club_url in enumerate(club_links):
        print(f"Scraping club {idx+1}/{len(club_links)}: {club_url}")
        players = get_players_from_club(club_url)
        all_players.extend(players)
        time.sleep(random.uniform(6, 10))

    df = pd.DataFrame(all_players)
    df.to_csv(f"../data/raw/{league_name}_players.csv", index=False)
    print(f"Saved data to data/raw/{league_name}_players.csv")
# Out:
# === Scraping Serie A ===
# Found 20 clubs.
# Scraping club 1/20: https://www.transfermarkt.com/ssc-neapel/kader/verein/6195/saison_id/2024
# Scraping club 2/20: https://www.transfermarkt.com/ac-mailand/kader/verein/5/saison_id/2024
# Scraping club 3/20: https://www.transfermarkt.com/fc-bologna/kader/verein/1025/saison_id/2024
# Scraping club 4/20: https://www.transfermarkt.com/fc-empoli/kader/verein/749/saison_id/2024
# Scraping club 5/20: https://www.transfermarkt.com/como-1907/kader/verein/1047/saison_id/2024
# Scraping club 6/20: https://www.transfermarkt.com/parma-calcio-1913/kader/verein/130/saison_id/2024
# Scraping club 7/20: https://www.transfermarkt.com/us-lecce/kader/verein/1005/saison_id/2024
# Scraping club 8/20: https://www.transfermarkt.com/genua-cfc/kader/verein/252/saison_id/2024
# Scraping club 9/20: https://www.transfermarkt.com/atalanta-bergamo/kader/verein/800/saison_id/2024
# Scraping club 10/20: https://www.transfermarkt.com/udinese-calcio/kader/verein/410/saison_id/2024
# Scraping club 11/20: https://www.transfermarkt.com/hellas-verona/kader/verein/276/saison_id/2024
# Scraping club 12/20: https://www.transfermarkt.com/lazio-rom/kader/verein/398/saison_id/2024
# Scraping club 13/20: https://www.transfermarkt.com/ac-monza/kader/verein/2919/saison_id/2024
# Scraping club 14/20: https://www.transfermarkt.com/cagliari-calcio/kader/verein/1390/saison_id/2024
# Scraping club 15/20: https://www.transfermarkt.com/inter-mailand/kader/verein/46/saison_id/2024
# Scraping club 16/20: https://www.transfermarkt.com/juventus-turin/kader/verein/506/saison_id/2024
# Scraping club 17/20: https://www.transfermarkt.com/ac-florenz/kader/verein/430/saison_id/2024
# Scraping club 18/20: https://www.transfermarkt.com/venezia-fc/kader/verein/607/saison_id/2024
# Scraping club 19/20: https://www.transfermarkt.com/as-rom/kader/verein/12/saison_id/2024
# Scraping club 20/20: https://www.transfermarkt.com/fc-turin/kader/verein/416/saison_id/2024
# Saved data to data/raw/serie_a_players.csv
#
# === Scraping La Liga ===
# Found 20 clubs.
# Scraping club 1/20: https://www.transfermarkt.com/real-sociedad-san-sebastian/kader/verein/681/saison_id/2024
# Scraping club 2/20: https://www.transfermarkt.com/rcd-mallorca/kader/verein/237/saison_id/2024
# Scraping club 3/20: https://www.transfermarkt.com/fc-valencia/kader/verein/1049/saison_id/2024
# Scraping club 4/20: https://www.transfermarkt.com/ca-osasuna/kader/verein/331/saison_id/2024
# Scraping club 5/20: https://www.transfermarkt.com/real-madrid/kader/verein/418/saison_id/2024
# Scraping club 6/20: https://www.transfermarkt.com/fc-girona/kader/verein/12321/saison_id/2024
# Scraping club 7/20: https://www.transfermarkt.com/deportivo-alaves/kader/verein/1108/saison_id/2024
# Scraping club 8/20: https://www.transfermarkt.com/fc-getafe/kader/verein/3709/saison_id/2024
# Scraping club 9/20: https://www.transfermarkt.com/fc-villarreal/kader/verein/1050/saison_id/2024
# Scraping club 10/20: https://www.transfermarkt.com/atletico-madrid/kader/verein/13/saison_id/2024
# Scraping club 11/20: https://www.transfermarkt.com/celta-vigo/kader/verein/940/saison_id/2024
# Scraping club 12/20: https://www.transfermarkt.com/real-betis-sevilla/kader/verein/150/saison_id/2024
# Scraping club 13/20: https://www.transfermarkt.com/rayo-vallecano/kader/verein/367/saison_id/2024
# Scraping club 14/20: https://www.transfermarkt.com/fc-sevilla/kader/verein/368/saison_id/2024
# Scraping club 15/20: https://www.transfermarkt.com/cd-leganes/kader/verein/1244/saison_id/2024
# Scraping club 16/20: https://www.transfermarkt.com/athletic-bilbao/kader/verein/621/saison_id/2024
# Scraping club 17/20: https://www.transfermarkt.com/fc-barcelona/kader/verein/131/saison_id/2024
# Scraping club 18/20: https://www.transfermarkt.com/ud-las-palmas/kader/verein/472/saison_id/2024
# Scraping club 19/20: https://www.transfermarkt.com/real-valladolid/kader/verein/366/saison_id/2024
# Scraping club 20/20: https://www.transfermarkt.com/espanyol-barcelona/kader/verein/714/saison_id/2024
# Saved data to data/raw/la_liga_players.csv
#
# === Scraping Bundesliga ===
# Found 18 clubs.
# Scraping club 1/18: https://www.transfermarkt.com/1-fsv-mainz-05/kader/verein/39/saison_id/2024
# Scraping club 2/18: https://www.transfermarkt.com/borussia-monchengladbach/kader/verein/18/saison_id/2024
# Scraping club 3/18: https://www.transfermarkt.com/vfb-stuttgart/kader/verein/79/saison_id/2024
# Scraping club 4/18: https://www.transfermarkt.com/tsg-1899-hoffenheim/kader/verein/533/saison_id/2024
# Scraping club 5/18: https://www.transfermarkt.com/borussia-dortmund/kader/verein/16/saison_id/2024
# Scraping club 6/18: https://www.transfermarkt.com/eintracht-frankfurt/kader/verein/24/saison_id/2024
# Scraping club 7/18: https://www.transfermarkt.com/1-fc-union-berlin/kader/verein/89/saison_id/2024
# Scraping club 8/18: https://www.transfermarkt.com/vfl-wolfsburg/kader/verein/82/saison_id/2024
# Scraping club 9/18: https://www.transfermarkt.com/sv-werder-bremen/kader/verein/86/saison_id/2024
# Scraping club 10/18: https://www.transfermarkt.com/1-fc-heidenheim-1846/kader/verein/2036/saison_id/2024
# Scraping club 11/18: https://www.transfermarkt.com/fc-st-pauli/kader/verein/35/saison_id/2024
# Scraping club 12/18: https://www.transfermarkt.com/holstein-kiel/kader/verein/269/saison_id/2024
# Scraping club 13/18: https://www.transfermarkt.com/fc-bayern-munchen/kader/verein/27/saison_id/2024
# Scraping club 14/18: https://www.transfermarkt.com/sc-freiburg/kader/verein/60/saison_id/2024
# Scraping club 15/18: https://www.transfermarkt.com/vfl-bochum/kader/verein/80/saison_id/2024
# Scraping club 16/18: https://www.transfermarkt.com/rasenballsport-leipzig/kader/verein/23826/saison_id/2024
# Scraping club 17/18: https://www.transfermarkt.com/fc-augsburg/kader/verein/167/saison_id/2024
# Scraping club 18/18: https://www.transfermarkt.com/bayer-04-leverkusen/kader/verein/15/saison_id/2024
# Saved data to data/raw/bundesliga_players.csv
#
# === Scraping Ligue 1 ===
# Found 18 clubs.
# Scraping club 1/18: https://www.transfermarkt.com/fc-toulouse/kader/verein/415/saison_id/2024
# Scraping club 2/18: https://www.transfermarkt.com/olympique-lyon/kader/verein/1041/saison_id/2024
# Scraping club 3/18: https://www.transfermarkt.com/fc-paris-saint-germain/kader/verein/583/saison_id/2024
# Scraping club 4/18: https://www.transfermarkt.com/fc-stade-rennes/kader/verein/273/saison_id/2024
# Scraping club 5/18: https://www.transfermarkt.com/ac-le-havre/kader/verein/738/saison_id/2024
# Scraping club 6/18: https://www.transfermarkt.com/sco-angers/kader/verein/1420/saison_id/2024
# Scraping club 7/18: https://www.transfermarkt.com/ogc-nizza/kader/verein/417/saison_id/2024
# Scraping club 8/18: https://www.transfermarkt.com/as-saint-etienne/kader/verein/618/saison_id/2024
# Scraping club 9/18: https://www.transfermarkt.com/stade-reims/kader/verein/1421/saison_id/2024
# Scraping club 10/18: https://www.transfermarkt.com/aj-auxerre/kader/verein/290/saison_id/2024
# Scraping club 11/18: https://www.transfermarkt.com/rc-lens/kader/verein/826/saison_id/2024
# Scraping club 12/18: https://www.transfermarkt.com/montpellier-hsc/kader/verein/969/saison_id/2024
# Scraping club 13/18: https://www.transfermarkt.com/as-monaco/kader/verein/162/saison_id/2024
# Scraping club 14/18: https://www.transfermarkt.com/losc-lille/kader/verein/1082/saison_id/2024
# Scraping club 15/18: https://www.transfermarkt.com/fc-nantes/kader/verein/995/saison_id/2024
# Scraping club 16/18: https://www.transfermarkt.com/rc-strassburg-alsace/kader/verein/667/saison_id/2024
# Scraping club 17/18: https://www.transfermarkt.com/stade-brest-29/kader/verein/3911/saison_id/2024
# Scraping club 18/18: https://www.transfermarkt.com/olympique-marseille/kader/verein/244/saison_id/2024
# Saved data to data/raw/ligue_1_players.csv
